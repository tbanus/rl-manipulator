# %%
# !pip install mujoco
# !pip install mujoco_mjx
# !pip install brax
# !git clone -l -s https://github.com/tbanus/rl-manipulator.git
# %cd rl-manipulator
# !ls
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
# !pip install glfw
# import mediapy as media

# %%
# #@title Check if MuJoCo installation was successful
# # %cd rl-manipulator
# import jax.numpy as jnp
# from jax import grad, jit, vmap
# from jax.nn import relu, softmax
# import mujoco
# from mujoco import mjx
# import mediapy as media
# import numpy as np
# import csv
# import os


# import jax
# import jax.numpy as jnp
# from jax.numpy.linalg import norm
# from jax import grad, jit, vmap
# from jax.nn import relu, softmax
# import mujoco
# from mujoco import mjx
# import mediapy as media
# import mujoco.mjx
# import subprocess
# import distutils.util
# # from google.colab import file

# import distutils.util
# import os
# import subprocess
# if subprocess.run('nvidia-smi').returncode:
#   raise RuntimeError(
#       'Cannot communicate with GPU. '
#       'Make sure you are using a GPU Colab runtime. '
#       'Go to the Runtime menu and select Choose runtime type.')

# # Add an ICD config so that glvnd can pick up the Nvidia EGL driver.
# # This is usually installed as part of an Nvidia driver package, but the Colab
# # kernel doesn't install its driver via APT, and as a result the ICD is missing.
# # (https://github.com/NVIDIA/libglvnd/blob/master/src/EGL/icd_enumeration.md)
# NVIDIA_ICD_CONFIG_PATH = '/usr/share/glvnd/egl_vendor.d/10_nvidia.json'
# if not os.path.exists(NVIDIA_ICD_CONFIG_PATH):
#   with open(NVIDIA_ICD_CONFIG_PATH, 'w') as f:
#     f.write("""{
#     "file_format_version" : "1.0.0",
#     "ICD" : {
#         "library_path" : "libEGL_nvidia.so.0"
#     }
# }
# """)

# # Tell XLA to use Triton GEMM, this improves steps/sec by ~30% on some GPUs
# xla_flags = os.environ.get('XLA_FLAGS', '')
# xla_flags += ' --xla_gpu_triton_gemm_any=True'
# os.environ['XLA_FLAGS'] = xla_flags

# # Configure MuJoCo to use the EGL rendering backend (requires GPU)
# print('Setting environment variable to use GPU rendering:')
# %env MUJOCO_GL=egl

# try:
#   print('Checking that the installation succeeded:')
#   import mujoco
#   mujoco.MjModel.from_xml_string('<mujoco/>')
# except Exception as e:
#   raise e from RuntimeError(
#       'Something went wrong during installation. Check the shell output above '
#       'for more information.\n'
#       'If using a hosted Colab runtime, make sure you enable GPU acceleration '
#       'by going to the Runtime menu and selecting "Choose runtime type".')

# print('Installation successful.')


# #@title Import packages for plotting and creating graphics
# import time
# import itertools
# import numpy as np
# from typing import Callable, NamedTuple, Optional, Union, List

# # Graphics and plotting.
# print('Installing mediapy:')
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
# import mediapy as media
# import matplotlib.pyplot as plt

# # More legible printing from numpy.
# np.set_printoptions(precision=3, suppress=True, linewidth=100)


# #@title Import MuJoCo, MJX, and Brax


# from datetime import datetime
# import functools
# from IPython.display import HTML
# import jax
# from jax import numpy as jnp
# from jax import jit, vmap
# import numpy as np
# from typing import Any, Dict, Sequence, Tuple, Union

# from brax import base
# from brax import envs
# from brax import math
# from brax.base import Base, Motion, Transform
# from brax.envs.base import Env, PipelineEnv, State
# from brax.mjx.base import State as MjxState
# from brax.training.agents.ppo import train as ppo
# from brax.training.agents.ppo import networks as ppo_networks
# from brax.io import html, mjcf, model

# from etils import epath
# from flax import struct
# from matplotlib import pyplot as plt
# import mediapy as media
# from ml_collections import config_dict
# import mujoco
# from mujoco import mjx

# %%
import jax
import jax.numpy as jnp
from jax import grad, jit, vmap
from jax.nn import relu, softmax
import mujoco
from mujoco import mjx
import mediapy as media
from MujocoSim import MujocoSim
import numpy as np
import csv
import os


import jax
import jax.numpy as jnp
from jax.numpy.linalg import norm
from jax import grad, jit, vmap
from jax.nn import relu, softmax
import mujoco
from mujoco import mjx
import mediapy as media
import mujoco.mjx
import subprocess
import distutils.util

os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false" 
if subprocess.run('nvidia-smi').returncode:
  raise RuntimeError(
      'Cannot communicate with GPU. '
      'Make sure you are using a GPU Colab runtime. '
      'Go to the Runtime menu and select Choose runtime type.')

# Add an ICD config so that glvnd can pick up the Nvidia EGL driver.
# This is usually installed as part of an Nvidia driver package, but the Colab
# kernel doesn't install its driver via APT, and as a result the ICD is missing.
# (https://github.com/NVIDIA/libglvnd/blob/master/src/EGL/icd_enumeration.md)
NVIDIA_ICD_CONFIG_PATH = '/usr/share/glvnd/egl_vendor.d/10_nvidia.json'
if not os.path.exists(NVIDIA_ICD_CONFIG_PATH):
  with open(NVIDIA_ICD_CONFIG_PATH, 'w') as f:
    f.write("""{
    "file_format_version" : "1.0.0",
    "ICD" : {
        "library_path" : "libEGL_nvidia.so.0"
    }
}
""")

# Tell XLA to use Triton GEMM, this improves steps/sec by ~30% on some GPUs
xla_flags = os.environ.get('XLA_FLAGS', '')
xla_flags += ' --xla_gpu_triton_gemm_any=True'
os.environ['XLA_FLAGS'] = xla_flags

# Configure MuJoCo to use the EGL rendering backend (requires GPU)
print('Setting environment variable to use GPU rendering:')
# %env MUJOCO_GL=egl

try:
  print('Checking that the installation succeeded:')
  import mujoco
  mujoco.MjModel.from_xml_string('<mujoco/>')
except Exception as e:
  raise e from RuntimeError(
      'Something went wrong during installation. Check the shell output above '
      'for more information.\n'
      'If using a hosted Colab runtime, make sure you enable GPU acceleration '
      'by going to the Runtime menu and selecting "Choose runtime type".')

print('Installation successful.')
# Out:
# Wed May 29 18:14:42 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.171.04             Driver Version: 535.171.04   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3080 ...    Off | 00000000:01:00.0 Off |                  N/A |
# | N/A   51C    P8              16W / 150W |      8MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2442      G   /usr/lib/xorg/Xorg                            4MiB |
# +---------------------------------------------------------------------------------------+
# Setting environment variable to use GPU rendering:
# env: MUJOCO_GL=egl
# Checking that the installation succeeded:
# Installation successful.

# %% [markdown]
# Environment

# %%
class MujocoSim:

    def __init__(self):
        # Initialize your environment
        # Make model, data, and renderer

        # states

        # 0-5: robot arm joints pos
        # 6: finger pos
        # 7-9: box pos
        # 10-13: box quat
        # 14-20: robot arm joints vel
        # 21: finger vel
        # 22-24: box vel
        # 25-27: box angular vel

        # actions
        # 0-5 :robot arm joints
        # 6: finger torque

        self.mj_model = mujoco.MjModel.from_xml_path('simple_arm/scene.xml')

        # self.mj_model.opt.solver = mujoco.mjtSolver.mjSOL_CG
        # self.mj_model.opt.iterations = 6
        # self.mj_model.opt.ls_iterations = 6
        self.mj_data = mujoco.MjData(self.mj_model)
        self.renderer = mujoco.Renderer(self.mj_model)
        # weight_load_target_dist_reward = 1
        # weight_tip_to_load_position_reward = 1
        # weight_tip_to_load_velocity_reward = 1
        # weight_current_torque_cost= 1
        # weight_peak_torque_cost= 1
        # weight_timestep = 1
        self.weights=jnp.array([-100,-45,0,-1,-1,0]).transpose()
        self.load_dest=jnp.array([1,1,1]).transpose()

        self.max_allowable_distance=4
        self.max_allowable_target_error=0.1
        # self.peak_torque=0

        self.mjx_model = mjx.put_model(self.mj_model)
        self.mjx_data = mjx.put_data(self.mj_model, self.mj_data)
        # self.mjx_data.replace(qpos=jnp.array([16e-6, -0.0007421, -0.047, 0.06 ,-4e-05 , 2.33e-5, 0.0009 ,0 ,3, 0 ,0.0198922, 1 ,0, 0 ,0]))


        # self.p=jnp.zeros([3,6]) #TODO
        # self.J=jnp.zeros([3,6])
    def reset(self):
        # Reset the environment to the initial state
        self.mj_model = mujoco.MjModel.from_xml_path('simple_arm/scene.xml')
        self.mj_model.opt.solver = mujoco.mjtSolver.mjSOL_CG
        # self.mj_model.opt.iterations = 6
        # self.mj_model.opt.ls_iterations = 6
        self.mj_data = mujoco.MjData(self.mj_model)
        # renderer = mujoco.Renderer(mj_model)

        self.weights=jnp.array([1,1,1,1,1,0.1]).transpose()
        self.load_dest=jnp.array([1,1,1]).transpose()



        self.mjx_model = mjx.put_model(self.mj_model)
        self.mjx_data = mjx.put_data(self.mj_model, self.mj_data)
        # self.mjx_data.replace(qpos=jnp.array([16e-6, -0.0007421, -0.047, 0.06 ,-4e-05 , 2.33e-5, 0.0009 ,0 ,5, 0 ,0.0198922, 1 ,0, 0 ,0]))



        return self.get_state(self.mjx_data)

    # @jax.vmap
    def step(self, model, data, action):
        # Execute the action and return the new state and reward
        # rng = jax.random.PRNGKey(0)
        # rng = jax.random.split(rng,1024)


        # fun=lambda rng: mjx_data.replace(ctrl=jax.random.uniform(rng, (8,)))
        # fun_vmapped = jax.vmap(fun)
        # batch=fun_vmapped(rng)
        # print(f"ac {action.shape}")
        # input=jnp.concatenate(action, jnp.zeros((7,)))
        # print(input.shape)
        data.replace(ctrl=action)
        # print("log_point1")
        for i in range(10):
            mjx.step(model, data)
        # print("log_point2")

        data=mjx.step(model, data)
        # print("log_point3")

        state=self.get_state(data)
        # print("log_point4")

        reward= self.get_reward(state,action)
        # print(f"debug info\n state, shape: {state}, {state.shape}\naction, shape:{action}, {action.shape}")

        # self.peak_torque=jnp.max(jnp.array([self.peak_torque, norm(jnp.array([action[0:6]]))**2]))
        return state, reward, data

        # fun_vmapped = jax.vmap(step, in_axes=(None,0,0))
        # batch=fun_vmapped(mjx_model, batch,rng)
        # jit_step = jax.jit(jax.vmap(step, in_axes=(None, 0,0)))
        # batch = jit_step(mjx_model, batch,rng)


    def batch_step(self, states, actions):
        batch = self.step(self.mjx_model, self.mjx_data, actions)

    def get_reward(self, state, action):
        #update peak torque(

        return sum([self.weights[0]*norm(state[7:10]-self.load_dest),
                    self.weights[1]*norm(state[7:10]-self.mjx_data.geom_xpos[16]),
                    self.weights[2]*norm(self.mjx_data.geom_xpos[16]-state[22:25]) ,
                    self.weights[3]*norm(action[0:6])**2 ,
                    self.weights[4]*1])

    def get_state(self,data):

        state=jnp.concatenate([data.qpos[0:7],data.qpos[7:14],data.qvel[0:7], data.qpos[7:13]])
        return state
    def isnt_done(self,state):
        rb = jnp.array(state[7:10]).transpose()
        rd=self.load_dest
        rm=jnp.array([0,0,0]).transpose()

        a=max([self.max_allowable_distance-norm(rb-rm),0])

        b=max([norm(rb-rd)-self.max_allowable_target_error,0])
        return a*b

# %% [markdown]
# Neural Networks

# %%
def clip_grads(grads, max_norm):
    norm = jnp.sqrt(sum(jnp.sum(g ** 2) for g in grads.values()))
    clip_coef = jnp.minimum(1.0, max_norm / (norm + 1e-6))
    return {k: v * clip_coef for k, v in grads.items()}
# Network definitions
@jit
def actor_network(params, state):

    # print(f"state {state}, w1 {params['W1']}, b1 {params['b1']}")

    hidden = relu(jnp.dot(state, params['W1']) + params['b1'])
    logits = jnp.dot(hidden, params['W2']) + params['b2']
    return softmax(logits)

@jit
def critic_network(params, state):

    hidden = relu(jnp.dot(state, params['W1']) + params['b1'])
    value = jnp.dot(hidden, params['W2']) + params['b2']
    return value


def initialize_params(input_dim, hidden_dim, output_dim):
    params = {
        'W1': jnp.array(np.random.randn(input_dim, hidden_dim) * 0.01),
        'b1': jnp.zeros(hidden_dim),
        'W2': jnp.array(np.random.randn(hidden_dim, output_dim) * 0.01),
        'b2': jnp.zeros(output_dim)
    }
    return params

input_dim = 27  # Example input dimension
hidden_dim = 128
output_dim_actor = 7  # Number of actions
output_dim_critic = 1  # Single value output

actor_params = initialize_params(input_dim, hidden_dim, output_dim_actor)
critic_params = initialize_params(input_dim, hidden_dim, output_dim_critic)

# %% [markdown]
# Actor Critic

# %%
class ActorCritic:
    def __init__(self, env : MujocoSim, actor_params : dict, critic_params : dict, lr : float=0.01):
        self.env = env
        self.actor_params = actor_params
        self.critic_params = critic_params
        self.lr = lr

    # @jit
    def select_action(self, state,actor_params):
        return actor_network(actor_params, state)
        # return jnp.ones([7,1])
    # @jit
    def update(self, state, action, reward, next_state, actor_params, critic_params):
        gamma = 0.99  # Discount factor
        max_grad_norm = 1.0  # Adjust as needed

        # Compute TD target
        value = critic_network(critic_params, state)
        next_value = critic_network(critic_params, next_state)
        td_target = reward + gamma * next_value
        td_error = td_target - value


        # print("tderr", td_error)
        # print("value", value)
        # print("reward",reward)
        # Update critic
        def critic_loss(params):
            value = critic_network(params, state)
            return jnp.mean((td_target - value) ** 2)

        # tde=(reward + 0.9 * critic_network(critic_params, next_state) - critic_network(critic_params, state)[0])


        critic_grads = grad(critic_loss)(critic_params)
        critic_grads = clip_grads(critic_grads, max_grad_norm)

        critic_params = {k: critic_params[k] + self.lr * critic_grads[k] for k in critic_params}


        key = jax.random.PRNGKey(0)
        std_devs=jnp.ones([7])*50



        def actor_loss(params):

            pi=jnp.abs(jax.random.normal(key,(1,7))*std_devs+actor_network(actor_params, state)[0])

            pi=jnp.where(pi>0.01, pi, 0.01)
            log_pi = jnp.log(pi)

            # print("logpi",log_pi)
            return jnp.mean(log_pi * td_error)

        actor_grads = grad(actor_loss)(actor_params)
        actor_grads = clip_grads(actor_grads, max_grad_norm)

        # print("actorgrad",actor_grads)
        # print("acc", actor_grads)
        # for k in actor_params:
        #     print(k)
        #     for i in actor_params[k]:
        #         print(i)
        pi = actor_network(actor_params, state)

        actor_params = {k: actor_params[k]  + self.lr * actor_grads[k] for k in actor_params}
        # actor_params['b2']=actor_params['b2']*pi
        # pi = actor_network(actor_params, state)

        # print(f"pi: {pi}, log_pi{ jnp.log(jnp.where(pi != 0., pi, 0.0001))},")
        return actor_params, critic_params


    def batch_train(self, episodes=EPISODES, batch_size=BATCH_SIZE):

        select_action=jax.vmap(self.select_action, in_axes=(0,None))


        update=jax.jit(jax.vmap(self.update, in_axes=(0,0,0,0,None,None)))
        # update_vmap=self.update


        batch=jax.vmap(lambda rng: self.env.mjx_data.replace(ctrl=jax.random.uniform(rng, (14,))))(jax.random.split(jax.random.PRNGKey(0),batch_size))
        get_state=jax.vmap(self.env.get_state)
        step=jax.jit(jax.vmap(self.env.step, in_axes=(None,0,0)))
        # step=jax.vmap(self.env.step, in_axes=(None,0,0))
        for episode in range(episodes):
            state = get_state(batch)
            #done = false
            action = select_action(state, self.actor_params)
            next_state, reward, batch = step(self.env.mjx_model, batch, action)
            if episode==0:
              self.log_header(jnp.mean(state, axis=0), jnp.mean(action, axis=0), jnp.mean(reward, axis=0))

            #visualize
            # renderer = mujoco.Renderer(self.env.mj_model)
            # frames=[]
            # framerate=100
            print("ep", episode)
            for i in range(N_STEPS):
                                
                print(f"current ep {episode}, step {i}")

                action = select_action(state, self.actor_params)
                # print(action.shape,"acsh")
                next_state, reward, batch = step(self.env.mjx_model, batch, action)

                # jax.debug.print(f"next_state.shape {next_state.shape} mean {jnp.mean(next_state, axis=0)}")


                actor_params,  critic_params = update(state, action, reward, next_state, self.actor_params, self.critic_params)
                for key in actor_params:
                    self.actor_params[key]=jnp.mean(actor_params[key], axis=0)
                    self.critic_params[key]=jnp.mean(critic_params[key], axis=0)
                # for i in range(batch_size):
                #      self.actor_params,  self.critic_params = update(state[i], action[i], reward[i], next_state[i], self.actor_params, self.critic_params)
                #     for key in actor_params:
                #         self.actor_params[key]=actor_params[key]

                #     for key in critic_params:
                #         self.critic_params[key]=critic_params[key]
                state = next_state
                self.log_line(jnp.mean(state, axis=0), jnp.mean(action, axis=0), jnp.mean(reward, axis=0))



    def train(self, episodes=EPISODES):

        reset=jax.jit(self.env.reset())

        for episode in range(episodes):
            reset()
            batch=self.env.mjx_data.replace(ctrl=jnp.ones([8]))

            state = jnp.zeros(27)

            done = False
            action = self.select_action(state, self.actor_params)
            next_state, reward, batch = self.env.step(self.env.mjx_model, batch, action)
            if episode==0:
              self.log_header(state,action,reward)
            renderer = mujoco.Renderer(self.env.mj_model)


            frames=[]
            framerate=100
            print("ep", episode)
            for i in range(N_STEPS):

                action = self.select_action(state, self.actor_params)


                next_state, reward, batch = self.env.step(self.env.mjx_model, batch, action)

                # jax.debug.print(f"next_state.shape {next_state.shape} mean {jnp.mean(next_state, axis=0)}")
                for i in range(1):
                    actor_params, critic_params = self.update(state, action, reward, next_state, self.actor_params, self.critic_params)
                    for key in actor_params:
                        self.actor_params[key]=actor_params[key]

                    for key in critic_params:
                        self.critic_params[key]=critic_params[key]
                state = next_state



                print(f"action: {action}")
                self.log_line(state,action,reward)


    # def update_parameters(self, mm, critic_params):

    def log_header(self,state, action, reward):
        header_text=[]
        for i in range(len(state)):
            header_text.append("state"+"_"+str(i) )
        for i in range(len(action)):
            header_text.append("action"+"_"+str(i))
        header_text.append("reward")
        filename="ac_log.csv"



        user_input = 'y'
        if user_input == 'y':
            file = 'logs/'+filename
            try:
                os.remove (file)
                data_f = open('logs/'+filename, 'a',newline='')
            except FileNotFoundError:
                data_f = open('logs/'+filename, 'x',newline='')
            # data_f = open('../opy_logs/'+filename, 'a',newline='')
            self.data_writer = csv.writer(data_f)
            Headers = header_text
            print(Headers)
            self.data_writer.writerow(Headers)
        else:
            data_f = open('logs/'+filename, 'a',newline='')
            data_writer = csv.writer(data_f)
    def log_newline(self):
        self.log_text=self.log_text+"0\n"
    def log_line(self, state, action, reward):

        LogList=[]
        # print(f"next_state.shape {state.shape} mean {str(state)}")
        # LogList.append(state)
        for i in state:
            LogList.append(str(i))
        for i in action:
            LogList.append(str(i))
        LogList.append(reward)
        self.data_writer.writerow(LogList)
    def save_parameters(self):
        LogList=[]
        # print(f"next_state.shape {state.shape} mean {str(state)}")

        filename="params.csv"
        file = 'logs/'+filename
        try:
            os.remove (file)
            data_f = open('logs/'+filename, 'a',newline='')
        except FileNotFoundError:
            data_f = open('logs/'+filename, 'x',newline='')
        # LogList.append(state)
        data_writer = csv.writer(data_f)
        for key in self.actor_params:
            LogList.append(key)
            for item in self.actor_params[key]:
                LogList.append(str(item))
        # print(f"next_state.shape {state.shape} mean {str(state)}")
        # LogList.append(state)
        for key in self.critic_params:
            LogList.append(key)
            for item in self.actor_params[key]:
                LogList.append(str(item))

        data_writer.writerow(LogList)
        # Vectorized operations using vmap
        # v_update = vmap(self.update, in_axes=(0, 0, 0, 0))
        # v_update(states, actions, rewards, next_states)


    # @jit
    # def batch_select_action(self, states):
    #     # Vectorized action selection
    #     v_select = vmap(self.select_action)
    #     return self.v_se lect(states)
    def use_parameters(self):
        self.env.reset()
        renderer = mujoco.Renderer(self.env.mj_model)

        if(1):
            print("use_parameters")
            batch=self.env.mjx_data.replace(ctrl=jnp.ones([14]))

            state = jnp.zeros(27)
            print("use_parameters")

            done = False
            action = self.select_action(state, self.actor_params)
            next_state, reward, batch = self.env.step(self.env.mjx_model, batch, action)
            if 1:
              self.log_header(state,action,reward)
            print("use_parameters")


            frames=[]
            framerate=100
            step=jax.jit(self.env.step)
            print("use_parameters", 1)
            for i in range(N_STEPS):

                action = self.select_action(state, self.actor_params)


                next_state, reward, batch =step(self.env.mjx_model, batch, action)

                # jax.debug.print(f"next_state.shape {next_state.shape} mean {jnp.mean(next_state, axis=0)}")
                # for i in range(1):
                #     actor_params, critic_params = self.update(state, action, reward, next_state, self.actor_params, self.critic_params)
                #     for key in actor_params:
                #         self.actor_params[key]=actor_params[key]

                #     for key in critic_params:
                #         self.critic_params[key]=critic_params[key]
                state = next_state
                # self.log_line(jnp.mean(state, axis=0), jnp.mean(action, axis=0), jnp.mean(reward, axis=0))
                mj_data = mjx.get_data(self.env.mj_model, batch)
                # mj_data=batched_mj_data[0]
                renderer.update_scene(mj_data)
                pixels = renderer.render()
                frames.append(pixels)
                self.log_line(state,action,reward)
            media.show_video(frames, fps=framerate)

# %% [markdown]
# Running

# %%
# import glfw
# Instantiate your environment
# renderer = mujoco.Renderer()

N_STEPS=1000
BATCH_SIZE=4096
EPISODES=100
env = MujocoSim()
# Create ActorCritic instance
ac = ActorCritic(env, actor_params, critic_params)

# # Train the model
print("begin")
ac.batch_train()
# ac.train()
# batch_train=jax.jit(ac.batch_train)
print("begsn")
# batch_train()



print("save params")
ac.save_parameters()
print("visualize one run")
ac.use_parameters()
# Out:
# begin
# ep 0
# current ep 0, step 0
# current ep 0, step 1
# current ep 0, step 2
# current ep 0, step 3
# current ep 0, step 4
# current ep 0, step 5
# current ep 0, step 6
# current ep 0, step 7
# current ep 0, step 8
# current ep 0, step 9
# current ep 0, step 10
# current ep 0, step 11
# current ep 0, step 12
# current ep 0, step 13
# current ep 0, step 14
# current ep 0, step 15
# current ep 0, step 16
# current ep 0, step 17
# current ep 0, step 18
# current ep 0, step 19
# current ep 0, step 20
# current ep 0, step 21
# current ep 0, step 22
# current ep 0, step 23
# current ep 0, step 24
# current ep 0, step 25
# current ep 0, step 26
# current ep 0, step 27
# current ep 0, step 28
# current ep 0, step 29
# current ep 0, step 30
# current ep 0, step 31
# current ep 0, step 32
# current ep 0, step 33
# current ep 0, step 34
# current ep 0, step 35
# current ep 0, step 36
# current ep 0, step 37
# current ep 0, step 38
# current ep 0, step 39
# current ep 0, step 40
# current ep 0, step 41
# current ep 0, step 42
# current ep 0, step 43
# current ep 0, step 44
# current ep 0, step 45
# current ep 0, step 46
# current ep 0, step 47
# current ep 0, step 48
# current ep 0, step 49
# current ep 0, step 50
# current ep 0, step 51
# current ep 0, step 52
# current ep 0, step 53
# current ep 0, step 54
# current ep 0, step 55
# current ep 0, step 56
# current ep 0, step 57
# current ep 0, step 58
# current ep 0, step 59
# current ep 0, step 60
# current ep 0, step 61
# current ep 0, step 62
# current ep 0, step 63
# current ep 0, step 64
# current ep 0, step 65
# current ep 0, step 66
# current ep 0, step 67
# current ep 0, step 68
# current ep 0, step 69
# current ep 0, step 70
# current ep 0, step 71
# current ep 0, step 72
# current ep 0, step 73
# current ep 0, step 74
# current ep 0, step 75
# current ep 0, step 76
# current ep 0, step 77
# current ep 0, step 78
# current ep 0, step 79
# current ep 0, step 80
# current ep 0, step 81
# current ep 0, step 82
# current ep 0, step 83
# current ep 0, step 84
# current ep 0, step 85
# current ep 0, step 86
# current ep 0, step 87
# current ep 0, step 88
# current ep 0, step 89
# current ep 0, step 90
# current ep 0, step 91
# current ep 0, step 92
# current ep 0, step 93
# current ep 0, step 94
# current ep 0, step 95
# current ep 0, step 96
# current ep 0, step 97
# current ep 0, step 98
# current ep 0, step 99
# ep 1
# current ep 1, step 0
# current ep 1, step 1
# current ep 1, step 2
# current ep 1, step 3
# current ep 1, step 4
# current ep 1, step 5
# current ep 1, step 6
# current ep 1, step 7
# current ep 1, step 8
# current ep 1, step 9
# current ep 1, step 10
# current ep 1, step 11
# current ep 1, step 12
# current ep 1, step 13
# current ep 1, step 14
# current ep 1, step 15
# current ep 1, step 16
# current ep 1, step 17
# current ep 1, step 18
# current ep 1, step 19
# current ep 1, step 20
# current ep 1, step 21
# current ep 1, step 22
# current ep 1, step 23
# current ep 1, step 24
# current ep 1, step 25
# current ep 1, step 26
# current ep 1, step 27
# current ep 1, step 28
# current ep 1, step 29
# current ep 1, step 30
# current ep 1, step 31
# current ep 1, step 32
# current ep 1, step 33
# current ep 1, step 34
# current ep 1, step 35
# current ep 1, step 36
# current ep 1, step 37
# current ep 1, step 38
# current ep 1, step 39
# current ep 1, step 40
# current ep 1, step 41
# current ep 1, step 42
# current ep 1, step 43
# current ep 1, step 44
# current ep 1, step 45
# current ep 1, step 46
# current ep 1, step 47
# current ep 1, step 48
# current ep 1, step 49
# current ep 1, step 50
# current ep 1, step 51
# current ep 1, step 52
# current ep 1, step 53
# current ep 1, step 54
# current ep 1, step 55
# current ep 1, step 56
# current ep 1, step 57
# current ep 1, step 58
# current ep 1, step 59
# current ep 1, step 60
# current ep 1, step 61
# current ep 1, step 62
# current ep 1, step 63
# current ep 1, step 64
# current ep 1, step 65
# current ep 1, step 66
# current ep 1, step 67
# current ep 1, step 68
# current ep 1, step 69
# current ep 1, step 70
# current ep 1, step 71
# current ep 1, step 72
# current ep 1, step 73
# current ep 1, step 74
# current ep 1, step 75
# current ep 1, step 76
# current ep 1, step 77
# current ep 1, step 78
# current ep 1, step 79
# current ep 1, step 80
# current ep 1, step 81
# current ep 1, step 82
# current ep 1, step 83
# current ep 1, step 84
# current ep 1, step 85
# current ep 1, step 86
# current ep 1, step 87
# current ep 1, step 88
# current ep 1, step 89
# current ep 1, step 90
# current ep 1, step 91
# current ep 1, step 92
# current ep 1, step 93
# current ep 1, step 94
# current ep 1, step 95
# current ep 1, step 96
# current ep 1, step 97
# current ep 1, step 98
# current ep 1, step 99
# ep 2
# current ep 2, step 0
# current ep 2, step 1
# current ep 2, step 2
# current ep 2, step 3
# current ep 2, step 4
# current ep 2, step 5
# current ep 2, step 6
# current ep 2, step 7
# current ep 2, step 8
# current ep 2, step 9
# current ep 2, step 10
# current ep 2, step 11
# current ep 2, step 12
# current ep 2, step 13
# current ep 2, step 14
# current ep 2, step 15
# current ep 2, step 16
# current ep 2, step 17
# current ep 2, step 18
# current ep 2, step 19
# current ep 2, step 20
# current ep 2, step 21
# current ep 2, step 22
# current ep 2, step 23
# current ep 2, step 24
# current ep 2, step 25
# current ep 2, step 26
# current ep 2, step 27
# current ep 2, step 28
# current ep 2, step 29
# current ep 2, step 30
# current ep 2, step 31
# current ep 2, step 32
# current ep 2, step 33
# current ep 2, step 34
# current ep 2, step 35
# current ep 2, step 36
# current ep 2, step 37
# current ep 2, step 38
# current ep 2, step 39
# current ep 2, step 40
# current ep 2, step 41
# current ep 2, step 42
# current ep 2, step 43
# current ep 2, step 44
# current ep 2, step 45
# current ep 2, step 46
# current ep 2, step 47
# current ep 2, step 48
# current ep 2, step 49
# current ep 2, step 50
# current ep 2, step 51
# current ep 2, step 52
# current ep 2, step 53
# current ep 2, step 54
# current ep 2, step 55
# current ep 2, step 56
# current ep 2, step 57
# current ep 2, step 58
# current ep 2, step 59
# current ep 2, step 60
# current ep 2, step 61
# current ep 2, step 62
# current ep 2, step 63
# current ep 2, step 64
# current ep 2, step 65
# current ep 2, step 66
# current ep 2, step 67
# current ep 2, step 68
# current ep 2, step 69
# current ep 2, step 70
# current ep 2, step 71
# current ep 2, step 72
# current ep 2, step 73
# current ep 2, step 74
# current ep 2, step 75
# current ep 2, step 76
# current ep 2, step 77
# current ep 2, step 78
# current ep 2, step 79
# current ep 2, step 80
# current ep 2, step 81
# current ep 2, step 82
# current ep 2, step 83
# current ep 2, step 84
# current ep 2, step 85
# current ep 2, step 86
# current ep 2, step 87
# current ep 2, step 88
# current ep 2, step 89
# current ep 2, step 90
# current ep 2, step 91
# current ep 2, step 92
# current ep 2, step 93
# current ep 2, step 94
# current ep 2, step 95
# current ep 2, step 96
# current ep 2, step 97
# current ep 2, step 98
# current ep 2, step 99
# ep 3
# current ep 3, step 0
# current ep 3, step 1
# current ep 3, step 2
# current ep 3, step 3
# current ep 3, step 4
# current ep 3, step 5
# current ep 3, step 6
# current ep 3, step 7
# current ep 3, step 8
# current ep 3, step 9
# current ep 3, step 10
# current ep 3, step 11
# current ep 3, step 12
# current ep 3, step 13
# current ep 3, step 14
# current ep 3, step 15
# current ep 3, step 16
# current ep 3, step 17
# current ep 3, step 18
# current ep 3, step 19
# current ep 3, step 20
# current ep 3, step 21
# current ep 3, step 22
# current ep 3, step 23
# current ep 3, step 24
# current ep 3, step 25
# current ep 3, step 26
# current ep 3, step 27
# current ep 3, step 28
# current ep 3, step 29
# current ep 3, step 30
# current ep 3, step 31
# current ep 3, step 32
# current ep 3, step 33
# current ep 3, step 34
# current ep 3, step 35
# current ep 3, step 36
# current ep 3, step 37
# current ep 3, step 38
# current ep 3, step 39
# current ep 3, step 40
# current ep 3, step 41
# current ep 3, step 42
# current ep 3, step 43
# current ep 3, step 44
# current ep 3, step 45
# current ep 3, step 46
# current ep 3, step 47
# current ep 3, step 48
# current ep 3, step 49
# current ep 3, step 50
# current ep 3, step 51
# current ep 3, step 52
# current ep 3, step 53
# current ep 3, step 54
# current ep 3, step 55
# current ep 3, step 56
# current ep 3, step 57
# current ep 3, step 58
# current ep 3, step 59
# current ep 3, step 60
# current ep 3, step 61
# current ep 3, step 62
# current ep 3, step 63
# current ep 3, step 64
# current ep 3, step 65
# current ep 3, step 66
# current ep 3, step 67
# current ep 3, step 68
# current ep 3, step 69
# current ep 3, step 70
# current ep 3, step 71
# current ep 3, step 72
# current ep 3, step 73
# current ep 3, step 74
# current ep 3, step 75
# current ep 3, step 76
# current ep 3, step 77
# current ep 3, step 78
# current ep 3, step 79
# current ep 3, step 80
# current ep 3, step 81
# current ep 3, step 82
# current ep 3, step 83
# current ep 3, step 84
# current ep 3, step 85
# current ep 3, step 86
# current ep 3, step 87
# current ep 3, step 88
# current ep 3, step 89
# current ep 3, step 90
# current ep 3, step 91
# current ep 3, step 92
# current ep 3, step 93
# current ep 3, step 94
# current ep 3, step 95
# current ep 3, step 96
# current ep 3, step 97
# current ep 3, step 98
# current ep 3, step 99
# ep 4
# current ep 4, step 0
# current ep 4, step 1
# current ep 4, step 2
# current ep 4, step 3
# current ep 4, step 4
# current ep 4, step 5
# current ep 4, step 6
# current ep 4, step 7
# current ep 4, step 8
# current ep 4, step 9
# current ep 4, step 10
# current ep 4, step 11
# current ep 4, step 12
# current ep 4, step 13
# current ep 4, step 14
# current ep 4, step 15
# current ep 4, step 16
# current ep 4, step 17
# current ep 4, step 18
# current ep 4, step 19
# current ep 4, step 20
# current ep 4, step 21
# current ep 4, step 22
# current ep 4, step 23
# current ep 4, step 24
# current ep 4, step 25
# current ep 4, step 26
# current ep 4, step 27
# current ep 4, step 28
# current ep 4, step 29
# current ep 4, step 30
# current ep 4, step 31
# current ep 4, step 32
# current ep 4, step 33
# current ep 4, step 34
# current ep 4, step 35
# current ep 4, step 36
# current ep 4, step 37
# current ep 4, step 38
# current ep 4, step 39
# current ep 4, step 40
# current ep 4, step 41
# current ep 4, step 42
# current ep 4, step 43
# current ep 4, step 44
# current ep 4, step 45
# current ep 4, step 46
# current ep 4, step 47
# current ep 4, step 48
# current ep 4, step 49
# current ep 4, step 50
# current ep 4, step 51
# current ep 4, step 52
# current ep 4, step 53
# current ep 4, step 54
# current ep 4, step 55
# current ep 4, step 56
# current ep 4, step 57
# current ep 4, step 58
# current ep 4, step 59
# current ep 4, step 60
# current ep 4, step 61
# current ep 4, step 62
# current ep 4, step 63
# current ep 4, step 64
# current ep 4, step 65
# current ep 4, step 66
# current ep 4, step 67
# current ep 4, step 68
# current ep 4, step 69
# current ep 4, step 70
# current ep 4, step 71
# current ep 4, step 72
# current ep 4, step 73
# current ep 4, step 74
# current ep 4, step 75
# current ep 4, step 76
# current ep 4, step 77
# current ep 4, step 78
# current ep 4, step 79
# current ep 4, step 80
# current ep 4, step 81
# current ep 4, step 82
# current ep 4, step 83
# current ep 4, step 84
# current ep 4, step 85
# current ep 4, step 86
# current ep 4, step 87
# current ep 4, step 88
# current ep 4, step 89
# current ep 4, step 90
# current ep 4, step 91
# current ep 4, step 92
# current ep 4, step 93
# current ep 4, step 94
# current ep 4, step 95
# current ep 4, step 96
# current ep 4, step 97
# current ep 4, step 98
# current ep 4, step 99
# ep 5
# current ep 5, step 0
# current ep 5, step 1
# current ep 5, step 2
# current ep 5, step 3
# current ep 5, step 4
# current ep 5, step 5
# current ep 5, step 6
# current ep 5, step 7
# current ep 5, step 8
# current ep 5, step 9
# current ep 5, step 10
# current ep 5, step 11
# current ep 5, step 12
# current ep 5, step 13
# current ep 5, step 14
# current ep 5, step 15
# current ep 5, step 16
# current ep 5, step 17
# current ep 5, step 18
# current ep 5, step 19
# current ep 5, step 20
# current ep 5, step 21
# current ep 5, step 22
# current ep 5, step 23
# current ep 5, step 24
# current ep 5, step 25
# current ep 5, step 26
# current ep 5, step 27
# current ep 5, step 28
# current ep 5, step 29
# current ep 5, step 30
# current ep 5, step 31
# current ep 5, step 32
# current ep 5, step 33
# current ep 5, step 34
# current ep 5, step 35
# current ep 5, step 36
# current ep 5, step 37
# current ep 5, step 38
# current ep 5, step 39
# current ep 5, step 40
# current ep 5, step 41
# current ep 5, step 42
# current ep 5, step 43
# current ep 5, step 44
# current ep 5, step 45
# current ep 5, step 46
# current ep 5, step 47
# current ep 5, step 48
# current ep 5, step 49
# current ep 5, step 50
# current ep 5, step 51
# current ep 5, step 52
# current ep 5, step 53
# current ep 5, step 54
# current ep 5, step 55
# current ep 5, step 56
# current ep 5, step 57
# current ep 5, step 58
# current ep 5, step 59
# current ep 5, step 60
# current ep 5, step 61
# current ep 5, step 62
# current ep 5, step 63
# current ep 5, step 64
# current ep 5, step 65
# current ep 5, step 66
# current ep 5, step 67
# current ep 5, step 68
# current ep 5, step 69
# current ep 5, step 70
# current ep 5, step 71
# current ep 5, step 72
# current ep 5, step 73
# current ep 5, step 74
# current ep 5, step 75
# current ep 5, step 76
# current ep 5, step 77
# current ep 5, step 78
# current ep 5, step 79
# current ep 5, step 80
# current ep 5, step 81
# current ep 5, step 82
# current ep 5, step 83
# current ep 5, step 84
# current ep 5, step 85
# current ep 5, step 86
# current ep 5, step 87
# current ep 5, step 88
# current ep 5, step 89
# current ep 5, step 90
# current ep 5, step 91
# current ep 5, step 92
# current ep 5, step 93
# current ep 5, step 94
# current ep 5, step 95
# current ep 5, step 96
# current ep 5, step 97
# current ep 5, step 98
# current ep 5, step 99
# ep 6
# current ep 6, step 0
# current ep 6, step 1
# current ep 6, step 2
# current ep 6, step 3
# current ep 6, step 4
# current ep 6, step 5
# current ep 6, step 6
# current ep 6, step 7
# current ep 6, step 8
# current ep 6, step 9
# current ep 6, step 10
# current ep 6, step 11
# current ep 6, step 12
# current ep 6, step 13
# current ep 6, step 14
# current ep 6, step 15
# current ep 6, step 16
# current ep 6, step 17
# current ep 6, step 18
# current ep 6, step 19
# current ep 6, step 20
# current ep 6, step 21
# current ep 6, step 22
# current ep 6, step 23
# current ep 6, step 24
# current ep 6, step 25
# current ep 6, step 26
# current ep 6, step 27
# current ep 6, step 28
# current ep 6, step 29
# current ep 6, step 30
# current ep 6, step 31
# current ep 6, step 32
# current ep 6, step 33
# current ep 6, step 34
# current ep 6, step 35
# current ep 6, step 36
# current ep 6, step 37
# current ep 6, step 38
# current ep 6, step 39
# current ep 6, step 40
# current ep 6, step 41
# current ep 6, step 42
# current ep 6, step 43
# current ep 6, step 44
# current ep 6, step 45
# current ep 6, step 46
# current ep 6, step 47
# current ep 6, step 48
# current ep 6, step 49
# current ep 6, step 50
# current ep 6, step 51
# current ep 6, step 52
# current ep 6, step 53
# current ep 6, step 54
# current ep 6, step 55
# current ep 6, step 56
# current ep 6, step 57
# current ep 6, step 58
# current ep 6, step 59
# current ep 6, step 60
# current ep 6, step 61
# current ep 6, step 62
# current ep 6, step 63
# current ep 6, step 64
# current ep 6, step 65
# current ep 6, step 66
# current ep 6, step 67
# current ep 6, step 68
# current ep 6, step 69
# current ep 6, step 70
# current ep 6, step 71
# current ep 6, step 72
# current ep 6, step 73
# current ep 6, step 74
# current ep 6, step 75
# current ep 6, step 76
# current ep 6, step 77
# current ep 6, step 78
# current ep 6, step 79
# current ep 6, step 80
# current ep 6, step 81
# current ep 6, step 82
# current ep 6, step 83
# current ep 6, step 84
# current ep 6, step 85
# current ep 6, step 86
# current ep 6, step 87
# current ep 6, step 88
# current ep 6, step 89
# current ep 6, step 90
# current ep 6, step 91
# current ep 6, step 92
# current ep 6, step 93
# current ep 6, step 94
# current ep 6, step 95
# current ep 6, step 96
# current ep 6, step 97
# current ep 6, step 98
# current ep 6, step 99
# ep 7
# current ep 7, step 0
# current ep 7, step 1
# current ep 7, step 2
# current ep 7, step 3
# current ep 7, step 4
# current ep 7, step 5
# current ep 7, step 6
# current ep 7, step 7
# current ep 7, step 8
# current ep 7, step 9
# current ep 7, step 10
# current ep 7, step 11
# current ep 7, step 12
# current ep 7, step 13
# current ep 7, step 14
# current ep 7, step 15
# current ep 7, step 16
# current ep 7, step 17
# current ep 7, step 18
# current ep 7, step 19
# current ep 7, step 20
# current ep 7, step 21
# current ep 7, step 22
# current ep 7, step 23
# current ep 7, step 24
# current ep 7, step 25
# current ep 7, step 26
# current ep 7, step 27
# current ep 7, step 28
# current ep 7, step 29
# current ep 7, step 30
# current ep 7, step 31
# current ep 7, step 32
# current ep 7, step 33
# current ep 7, step 34
# current ep 7, step 35
# current ep 7, step 36
# current ep 7, step 37
# current ep 7, step 38
# current ep 7, step 39
# current ep 7, step 40
# current ep 7, step 41
# current ep 7, step 42
# current ep 7, step 43
# current ep 7, step 44
# current ep 7, step 45
# current ep 7, step 46
# current ep 7, step 47
# current ep 7, step 48
# current ep 7, step 49
# current ep 7, step 50
# current ep 7, step 51
# current ep 7, step 52
# current ep 7, step 53
# current ep 7, step 54
# current ep 7, step 55
# current ep 7, step 56
# current ep 7, step 57
# current ep 7, step 58
# current ep 7, step 59
# current ep 7, step 60
# current ep 7, step 61
# current ep 7, step 62
# current ep 7, step 63
# current ep 7, step 64
# current ep 7, step 65
# current ep 7, step 66
# current ep 7, step 67
# current ep 7, step 68
# current ep 7, step 69
# current ep 7, step 70
# current ep 7, step 71
# current ep 7, step 72
# current ep 7, step 73
# current ep 7, step 74
# current ep 7, step 75
# current ep 7, step 76
# current ep 7, step 77
# current ep 7, step 78
# current ep 7, step 79
# current ep 7, step 80
# current ep 7, step 81
# current ep 7, step 82
# current ep 7, step 83
# current ep 7, step 84
# current ep 7, step 85
# current ep 7, step 86
# current ep 7, step 87
# current ep 7, step 88
# current ep 7, step 89
# current ep 7, step 90
# current ep 7, step 91
# current ep 7, step 92
# current ep 7, step 93
# current ep 7, step 94
# current ep 7, step 95
# current ep 7, step 96
# current ep 7, step 97
# current ep 7, step 98
# current ep 7, step 99
# ep 8
# current ep 8, step 0
# current ep 8, step 1
# current ep 8, step 2
# current ep 8, step 3
# current ep 8, step 4
# current ep 8, step 5
# current ep 8, step 6
# current ep 8, step 7
# current ep 8, step 8
# current ep 8, step 9
# current ep 8, step 10
# current ep 8, step 11
# current ep 8, step 12
# current ep 8, step 13
# current ep 8, step 14
# current ep 8, step 15
# current ep 8, step 16
# current ep 8, step 17
# current ep 8, step 18
# current ep 8, step 19
# current ep 8, step 20
# current ep 8, step 21
# current ep 8, step 22
# current ep 8, step 23
# current ep 8, step 24
# current ep 8, step 25
# current ep 8, step 26
# current ep 8, step 27
# current ep 8, step 28
# current ep 8, step 29
# current ep 8, step 30
# current ep 8, step 31
# current ep 8, step 32
# current ep 8, step 33
# current ep 8, step 34
# current ep 8, step 35
# current ep 8, step 36
# current ep 8, step 37
# current ep 8, step 38
# current ep 8, step 39
# current ep 8, step 40
# current ep 8, step 41
# current ep 8, step 42
# current ep 8, step 43
# current ep 8, step 44
# current ep 8, step 45
# current ep 8, step 46
# current ep 8, step 47
# current ep 8, step 48
# current ep 8, step 49
# current ep 8, step 50
# current ep 8, step 51
# current ep 8, step 52
# current ep 8, step 53
# current ep 8, step 54
# current ep 8, step 55
# current ep 8, step 56
# current ep 8, step 57
# current ep 8, step 58
# current ep 8, step 59
# current ep 8, step 60
# current ep 8, step 61
# current ep 8, step 62
# current ep 8, step 63
# current ep 8, step 64
# current ep 8, step 65
# current ep 8, step 66
# current ep 8, step 67
# current ep 8, step 68
# current ep 8, step 69
# current ep 8, step 70
# current ep 8, step 71
# current ep 8, step 72
# current ep 8, step 73
# current ep 8, step 74
# current ep 8, step 75
# current ep 8, step 76
# current ep 8, step 77
# current ep 8, step 78
# current ep 8, step 79
# current ep 8, step 80
# current ep 8, step 81
# current ep 8, step 82
# current ep 8, step 83
# current ep 8, step 84
# current ep 8, step 85
# current ep 8, step 86
# current ep 8, step 87
# current ep 8, step 88
# current ep 8, step 89
# current ep 8, step 90
# current ep 8, step 91
# current ep 8, step 92
# current ep 8, step 93
# current ep 8, step 94
# current ep 8, step 95
# current ep 8, step 96
# current ep 8, step 97
# current ep 8, step 98
# current ep 8, step 99
# ep 9
# current ep 9, step 0
# current ep 9, step 1
# current ep 9, step 2
# current ep 9, step 3
# current ep 9, step 4
# current ep 9, step 5
# current ep 9, step 6
# current ep 9, step 7
# current ep 9, step 8
# current ep 9, step 9
# current ep 9, step 10
# current ep 9, step 11
# current ep 9, step 12
# current ep 9, step 13
# current ep 9, step 14
# current ep 9, step 15
# current ep 9, step 16
# current ep 9, step 17
# current ep 9, step 18
# current ep 9, step 19
# current ep 9, step 20
# current ep 9, step 21
# current ep 9, step 22
# current ep 9, step 23
# current ep 9, step 24
# current ep 9, step 25
# current ep 9, step 26
# current ep 9, step 27
# current ep 9, step 28
# current ep 9, step 29
# current ep 9, step 30
# current ep 9, step 31
# current ep 9, step 32
# current ep 9, step 33
# current ep 9, step 34
# current ep 9, step 35
# current ep 9, step 36
# current ep 9, step 37
# current ep 9, step 38
# current ep 9, step 39
# current ep 9, step 40
# current ep 9, step 41
# current ep 9, step 42
# current ep 9, step 43
# current ep 9, step 44
# current ep 9, step 45
# current ep 9, step 46
# current ep 9, step 47
# current ep 9, step 48
# current ep 9, step 49
# current ep 9, step 50
# current ep 9, step 51
# current ep 9, step 52
# current ep 9, step 53
# current ep 9, step 54
# current ep 9, step 55
# current ep 9, step 56
# current ep 9, step 57
# current ep 9, step 58
# current ep 9, step 59
# current ep 9, step 60
# current ep 9, step 61
# current ep 9, step 62
# current ep 9, step 63
# current ep 9, step 64
# current ep 9, step 65
# current ep 9, step 66
# current ep 9, step 67
# current ep 9, step 68
# current ep 9, step 69
# current ep 9, step 70
# current ep 9, step 71
# current ep 9, step 72
# current ep 9, step 73
# current ep 9, step 74
# current ep 9, step 75
# current ep 9, step 76
# current ep 9, step 77
# current ep 9, step 78
# current ep 9, step 79
# current ep 9, step 80
# current ep 9, step 81
# current ep 9, step 82
# current ep 9, step 83
# current ep 9, step 84
# current ep 9, step 85
# current ep 9, step 86
# current ep 9, step 87
# current ep 9, step 88
# current ep 9, step 89
# current ep 9, step 90
# current ep 9, step 91
# current ep 9, step 92
# current ep 9, step 93
# current ep 9, step 94
# current ep 9, step 95
# current ep 9, step 96
# current ep 9, step 97
# current ep 9, step 98
# current ep 9, step 99
# begsn
# save params
# visualize one run
# use_parameters
# use_parameters
# ['state_0', 'state_1', 'state_2', 'state_3', 'state_4', 'state_5', 'state_6', 'state_7', 'state_8', 'state_9', 'state_10', 'state_11', 'state_12', 'state_13', 'state_14', 'state_15', 'state_16', 'state_17', 'state_18', 'state_19', 'state_20', 'state_21', 'state_22', 'state_23', 'state_24', 'state_25', 'state_26', 'action_0', 'action_1', 'action_2', 'action_3', 'action_4', 'action_5', 'action_6', 'reward']
# use_parameters
# use_parameters 1
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
# ac.use_parameters()

# renderer = mujoco.Renderer(env.mj_model)
